# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('StudentPerformanceFactors.csv')
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# # Columns needs to be encoded
# - Parental_Involvement
# - Access_to_Resources
# - Extracurricular_Activities
# - Motivation_Level
# - Internet_Access
# - Family_Income
# - Teacher_Quality
# - School_Type
# - Peer_Influence
# - Learning_Disabilities
# - Parental_Education_Level
# - Distance_from_Home
# - Gender

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
# First encode using one hot encoding
one_hot = pd.get_dummies(df['Parental_Involvement'], prefix='Parental_Involvement').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Parental_Involvement', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Access_to_Resources Extracurricular_Activities  \
# 0             23          84                High                         No
# 1             19          64              Medium                         No
# 2             24          98              Medium                        Yes
# 3             29          89              Medium                        Yes
# 4             19          92              Medium                        Yes
#
#    Sleep_Hours  Previous_Scores Motivation_Level Internet_Access  \
# 0            7               73              Low             Yes
# 1            8               59              Low             Yes
# 2            7               91           Medium             Yes
# 3            8               98           Medium             Yes
# 4            6               65           Medium             Yes
#
#    Tutoring_Sessions Family_Income  ... Peer_Influence Physical_Activity  \
# ...

# %%
one_hot = pd.get_dummies(df['Access_to_Resources'], prefix='Access_to_Resources').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Access_to_Resources', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Extracurricular_Activities  Sleep_Hours  \
# 0             23          84                         No            7
# 1             19          64                         No            8
# 2             24          98                        Yes            7
# 3             29          89                        Yes            8
# 4             19          92                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  Tutoring_Sessions  \
# 0               73              Low             Yes                  0
# 1               59              Low             Yes                  2
# 2               91           Medium             Yes                  2
# 3               98           Medium             Yes                  1
# 4               65           Medium             Yes                  3
#
#   Family_Income Teacher_Quality  ... Parental_Education_Level  \
# ...

# %%
#Extracurricular_Activities
one_hot = pd.get_dummies(df['Extracurricular_Activities'], prefix='Extracurricular_Activities').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Extracurricular_Activities', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0             23          84            7               73              Low
# 1             19          64            8               59              Low
# 2             24          98            7               91           Medium
# 3             29          89            8               98           Medium
# 4             19          92            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type  ...  Gender  Exam_Score Parental_Involvement_High  \
# ...

# %%
#Motivation_Level
one_hot = pd.get_dummies(df['Motivation_Level'], prefix='Motivation_Level').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Motivation_Level', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores Internet_Access  \
# 0             23          84            7               73             Yes
# 1             19          64            8               59             Yes
# 2             24          98            7               91             Yes
# 3             29          89            8               98             Yes
# 4             19          92            6               65             Yes
#
#    Tutoring_Sessions Family_Income Teacher_Quality School_Type Peer_Influence  \
# 0                  0           Low          Medium      Public       Positive
# 1                  2        Medium          Medium      Public       Negative
# 2                  2        Medium          Medium      Public        Neutral
# 3                  1        Medium          Medium      Public       Negative
# 4                  3        Medium            High      Public        Neutral
#
# ...

# %%
#Internet_Access
one_hot = pd.get_dummies(df['Internet_Access'], prefix='Internet_Access').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Internet_Access', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#   Family_Income Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0           Low          Medium      Public       Positive                  3
# 1        Medium          Medium      Public       Negative                  4
# 2        Medium          Medium      Public        Neutral                  4
# 3        Medium          Medium      Public       Negative                  4
# 4        Medium            High      Public        Neutral                  4
#
# ...

# %%
#Family_Income
one_hot = pd.get_dummies(df['Family_Income'], prefix='Family_Income').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Family_Income', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#   Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0          Medium      Public       Positive                  3
# 1          Medium      Public       Negative                  4
# 2          Medium      Public        Neutral                  4
# 3          Medium      Public       Negative                  4
# 4            High      Public        Neutral                  4
#
#   Learning_Disabilities  ... Extracurricular_Activities_No  \
# ...

# %%
#Teacher_Quality
one_hot = pd.get_dummies(df['Teacher_Quality'], prefix='Teacher_Quality').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Teacher_Quality', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
# ...

# %%
#School_Type
one_hot = pd.get_dummies(df['School_Type'], prefix='School_Type').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('School_Type', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#   Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0       Positive                  3                    No
# 1       Negative                  4                    No
# 2        Neutral                  4                    No
# 3       Negative                  4                    No
# 4        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  ... Internet_Access_No  \
# 0              High School               Near  ...                  0
# ...

# %%
#Peer_Influence
one_hot = pd.get_dummies(df['Peer_Influence'], prefix='Peer_Influence').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Peer_Influence', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity Learning_Disabilities Parental_Education_Level  \
# 0                  3                    No              High School
# 1                  4                    No                  College
# 2                  4                    No             Postgraduate
# 3                  4                    No              High School
# 4                  4                    No                  College
#
#   Distance_from_Home  Gender  ...  Family_Income_Low  Family_Income_Medium  \
# ...

# %%
#Learning_Disabilities
one_hot = pd.get_dummies(df['Learning_Disabilities'], prefix='Learning_Disabilities').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Learning_Disabilities', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity Parental_Education_Level Distance_from_Home  Gender  \
# 0                  3              High School               Near    Male
# 1                  4                  College           Moderate  Female
# 2                  4             Postgraduate               Near    Male
# 3                  4              High School           Moderate    Male
# 4                  4                  College               Near  Female
#
# ...

# %%
#Parental_Education_Level
one_hot = pd.get_dummies(df['Parental_Education_Level'], prefix='Parental_Education_Level').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Parental_Education_Level', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity Distance_from_Home  Gender  Exam_Score  \
# 0                  3               Near    Male          67
# 1                  4           Moderate  Female          61
# 2                  4               Near    Male          74
# 3                  4           Moderate    Male          71
# 4                  4               Near  Female          70
#
#    Parental_Involvement_High  ...  School_Type_Private  School_Type_Public  \
# ...

# %%
#Distance_from_Home
one_hot = pd.get_dummies(df['Distance_from_Home'], prefix='Distance_from_Home').astype(int)
df = pd.concat([df, one_hot], axis=1)
df.drop('Distance_from_Home', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity  Gender  Exam_Score  Parental_Involvement_High  \
# 0                  3    Male          67                          0
# 1                  4  Female          61                          0
# 2                  4    Male          74                          0
# 3                  4    Male          71                          0
# 4                  4  Female          70                          0
#
#    Parental_Involvement_Low  ...  Peer_Influence_Neutral  \
# ...

# %%
#Gender
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity  Gender  Exam_Score  Parental_Involvement_High  \
# 0                  3       0          67                          0
# 1                  4       1          61                          0
# 2                  4       0          74                          0
# 3                  4       0          71                          0
# 4                  4       1          70                          0
#
#    Parental_Involvement_Low  ...  Peer_Influence_Neutral  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Hours_Studied                          6607 non-null   int64
#  1   Attendance                             6607 non-null   int64
#  2   Sleep_Hours                            6607 non-null   int64
#  3   Previous_Scores                        6607 non-null   int64
#  4   Tutoring_Sessions                      6607 non-null   int64
#  5   Physical_Activity                      6607 non-null   int64
#  6   Gender                                 6607 non-null   int64
#  7   Exam_Score                             6607 non-null   int64
#  8   Parental_Involvement_High              6607 non-null   int32
#  9   Parental_Involvement_Low               6607 non-null   int32
#  10  Parental_Involvement_Medium            6607 non-null   int32
# ...

# %%
for column in df.columns:
    plt.figure(figsize=(14, 4))
    if pd.api.types.is_numeric_dtype(df[column]):
        # For numeric columns, use a histogram
        plt.hist(df[column], bins=10, color='skyblue', edgecolor='black')
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
    else:
        # For categorical columns, use a bar chart
        df[column].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
        plt.title(f'Bar Chart of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
    
    # Show plot
    plt.tight_layout()
    plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(50, 50))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Standardization
# After looking at the data we can see that the data has a normal distribution, so we can use the StandardScaler (Z-Score) to standardize the data.
# **Some Data are not normally distributed, so we can use the MinMaxScaler to standardize the data.**
